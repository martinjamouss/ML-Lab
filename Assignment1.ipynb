# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
df=pd.read_csv('/content/gdrive/MyDrive/project2data.csv')

# %%
plt.figure(figsize=(12,5))
plt.plot(df['bmi'])
plt.title('BMI Across Different Individuals')
plt.ylabel('BMI')
plt.xlabel('Individual ID')
# Out:
# Text(0.5, 0, 'Individual ID')

# %% [markdown]
# The graph shows the BMI levels of different individuals.
